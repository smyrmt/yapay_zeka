# %%
import pandas as pd
import numpy as np

# %%
liste=[1,2,3,"a","b","c"]

# %%
liste=np.array([1,2,3,"a","b","c"])
liste.dtype
# Out:
# dtype('<U11')

# %%
df=pd.DataFrame(liste, columns=["veri"])

# %%
df
# Out:
#   veri
# 0    1
# 1    2
# 2    3
# 3    a
# 4    b
# 5    c

# %% [markdown]
# **Veri İnceleme**
# info(), axes, shape, ndim, size, values, head, tail

# %%
#ilk önce numpy ile rasgele bir dizi oluşturalım
import numpy as np
#veriler=np.random.randint(1,100,size=(3,3))
veriler=np.random.randint(1,100,([3,3]))

# %%
veriler
# Out:
# array([[28, 33, 93],
#        [35, 51, 48],
#        [52, 11, 46]])

# %%
#oluşturduğumuz bu diziyi dataframe'e çevirelim
df=pd.DataFrame(veriler,index=["veri1","veri2","veri3"],columns=["sütun1","sütun2","sütun3"])
df
# Out:
#        sütun1  sütun2  sütun3
# veri1      28      33      93
# veri2      35      51      48
# veri3      52      11      46

# %%
veriler=[["Sumeyra","Muti",33],["Hüma","Muti",14]]

# %%
data_frame=pd.DataFrame(veriler, index=["ogr1","ogr2"])

# %%
df=pd.DataFrame(veriler, columns=["isim","soyisim","yaş"])

# %%
df
# Out:
#       isim soyisim  yaş
# 0  Sumeyra    Muti   33
# 1     Hüma    Muti   14

# %%
df.info()#dataframe hakkında genel bilgi. Soru: veriler np olsaydı ne olurdu?
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   isim     2 non-null      object
#  1   soyisim  2 non-null      object
#  2   yaş      2 non-null      int64
# dtypes: int64(1), object(2)
# memory usage: 180.0+ bytes

# %%
df.axes#dataframe'in satır ve sütun bilgileri
# Out:
# [RangeIndex(start=0, stop=2, step=1),
#  Index(['isim', 'soyisim', 'yaş'], dtype='object')]

# %%
df.shape#dataframe kaç satır kaç sütundan oluşuyor
# Out:
# (2, 3)

# %%
df.ndim#dataframekaç boyutlu
# Out:
# 2

# %%
df.size#dataframe kaç veriden oluşuyor
# Out:
# 6

# %%
df.head(1)#dataframe'in ilk 1 satırını verir
# Out:
#       isim soyisim  yaş
# 0  Sumeyra    Muti   33

# %%
df.tail(1)#dataframe'in son 1 satırını verir
# Out:
#    isim soyisim  yaş
# 1  Hüma    Muti   14

# %% [markdown]
# ************************************
# __veri setini içeri aktarma__

# %%
df=pd.read_csv("diabetes_data_upload.csv")
df
# Out:
#      Age  Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 0     40    Male       No        Yes                 No      Yes         No
# 1     58    Male       No         No                 No      Yes         No
# 2     41    Male      Yes         No                 No      Yes        Yes
# 3     45    Male       No         No                Yes      Yes        Yes
# 4     60    Male      Yes        Yes                Yes      Yes        Yes
# ..   ...     ...      ...        ...                ...      ...        ...
# 515   39  Female      Yes        Yes                Yes       No        Yes
# 516   48  Female      Yes        Yes                Yes      Yes        Yes
# 517   58  Female      Yes        Yes                Yes      Yes        Yes
# 518   32  Female       No         No                 No      Yes         No
# 519   42    Male       No         No                 No       No         No
#
# ...

# %% [markdown]
# **Satır, Sütun Seçme İşlemleri**

# %%
#Belli bir satırı seçme
df.iloc[0] #0 indeksli satırı gösterir
# Out:
# Age                         40
# Gender                    Male
# Polyuria                    No
# Polydipsia                 Yes
# sudden weight loss          No
# weakness                   Yes
# Polyphagia                  No
# Genital thrush              No
# visual blurring             No
# Itching                    Yes
# Irritability                No
# delayed healing            Yes
# partial paresis             No
# muscle stiffness           Yes
# Alopecia                   Yes
# Obesity                    Yes
# class                 Positive
# Name: 0, dtype: object

# %%
#belli bir satır aralığını gösterme
df.iloc[0:4] #0 indexli satırdan başlayarak 4 indeksli satıra kadar olan satırları gösterir
# Out:
#    Age Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 0   40   Male       No        Yes                 No      Yes         No
# 1   58   Male       No         No                 No      Yes         No
# 2   41   Male      Yes         No                 No      Yes        Yes
# 3   45   Male       No         No                Yes      Yes        Yes
#
#   Genital thrush visual blurring Itching Irritability delayed healing  \
# 0             No              No     Yes           No             Yes
# 1             No             Yes      No           No              No
# 2             No              No     Yes           No             Yes
# 3            Yes              No     Yes           No             Yes
#
#   partial paresis muscle stiffness Alopecia Obesity     class
# 0              No              Yes      Yes     Yes  Positive
# 1             Yes               No      Yes      No  Positive
# ...

# %%
df.iloc[2:7] #Ne sonuç verir?

# %%
#belli sütunları seçme
df.iloc[:,0:5] #0 indeksli sütundan 5 indeksli sütuna kadar bütün satırları göster
# Out:
#      Age  Gender Polyuria Polydipsia sudden weight loss
# 0     40    Male       No        Yes                 No
# 1     58    Male       No         No                 No
# 2     41    Male      Yes         No                 No
# 3     45    Male       No         No                Yes
# 4     60    Male      Yes        Yes                Yes
# ..   ...     ...      ...        ...                ...
# 515   39  Female      Yes        Yes                Yes
# 516   48  Female      Yes        Yes                Yes
# 517   58  Female      Yes        Yes                Yes
# 518   32  Female       No         No                 No
# 519   42    Male       No         No                 No
#
# [520 rows x 5 columns]

# %%
df.iloc[:,3:7] #3 indeksli sütundan 7 indeksli sütuna kadar bütün satırları göster
# Out:
#     Polydipsia sudden weight loss weakness Polyphagia
# 0          Yes                 No      Yes         No
# 1           No                 No      Yes         No
# 2           No                 No      Yes        Yes
# 3           No                Yes      Yes        Yes
# 4          Yes                Yes      Yes        Yes
# ..         ...                ...      ...        ...
# 515        Yes                Yes       No        Yes
# 516        Yes                Yes      Yes        Yes
# 517        Yes                Yes      Yes        Yes
# 518         No                 No      Yes         No
# 519         No                 No       No         No
#
# [520 rows x 4 columns]

# %%
#SORU: 5. satırdan 17. satıra kadar olan verilerin "Gender" sütununu göster

# %%
yeni_df=df.iloc[:,0:5]

# %%
yeni_df
# Out:
#      Age  Gender Polyuria Polydipsia sudden weight loss
# 0     40    Male       No        Yes                 No
# 1     58    Male       No         No                 No
# 2     41    Male      Yes         No                 No
# 3     45    Male       No         No                Yes
# 4     60    Male      Yes        Yes                Yes
# ..   ...     ...      ...        ...                ...
# 515   39  Female      Yes        Yes                Yes
# 516   48  Female      Yes        Yes                Yes
# 517   58  Female      Yes        Yes                Yes
# 518   32  Female       No         No                 No
# 519   42    Male       No         No                 No
#
# [520 rows x 5 columns]

# %%
yeni_df.columns=["Yaş","Cinsiyet","Poliüre","Polidipsi","Ani Kilo Kaybı"]
yeni_df
# Out:
#      Yaş Cinsiyet Poliüre Polidipsi Ani Kilo Kaybı
# 0     40     Male      No       Yes             No
# 1     58     Male      No        No             No
# 2     41     Male     Yes        No             No
# 3     45     Male      No        No            Yes
# 4     60     Male     Yes       Yes            Yes
# ..   ...      ...     ...       ...            ...
# 515   39   Female     Yes       Yes            Yes
# 516   48   Female     Yes       Yes            Yes
# 517   58   Female     Yes       Yes            Yes
# 518   32   Female      No        No             No
# 519   42     Male      No        No             No
#
# [520 rows x 5 columns]

# %%
#Ice Cream veri setini içeri aktar

# %%
#veri setinin bilgilerini göster

# %%
#ilk 15 satırı göster

# %%
#son 5 satırı göster

# %%
#dataframe'in kaç satır ve sütundan oluştuğunu göster

# %%
#dataframe'in boyutunu göster

# %%
#veri setinin kaç adet veriden oluştuğunu göster

# %%
#Revenue sütununun bilgilerini göster
